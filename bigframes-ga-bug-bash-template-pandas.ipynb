# %% [markdown]
# # Setup

# %%
# Verify pandas version is 1.5.3
import pandas
pandas.__version__
# Out:
# '1.5.3'

# %%
# Run the following command if the pandas version is not 1.5.3
# pip install pandas==1.5.3

# %%
# Verify bigframes version is 0.23.0
import bigframes
bigframes.__version__
# Out:
# '0.23.0'

# %%
# Run the following command if the bigframes version is not 0.23.0
# pip install bigframes==0.23.0

# %%
import pandas as pandas
import pyarrow as pa
import numpy as np

PROJECT_ID = 'bigframes-bugbash-pandas'
REGION = 'us'

import bigframes.pandas as pd
# pd.options.display.progress_bar = None
pd.options.bigquery.project = PROJECT_ID
pd.options.bigquery.location = REGION

# %% [markdown]
# # Cheat sheet

# %% [markdown]
# ## 1. Object types
#
# There are 3 BigFrames native object types:
# 1. Dataframe
# 2. Series
# 3. Index

# %%
# Dataframe - 2 colums by 3 rows with index
pd.DataFrame({'A': [1, 2, 3], 'B': ['a', 'b', 'c']}, index=['x', 'y', 'z'])
# Out:
# Query job 0b251c06-a811-42b6-ad44-d3b598382961 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:0b251c06-a811-42b6-ad44-d3b598382961&page=queryresults">Open Job</a>
#    A  B
# x  1  a
# y  2  b
# z  3  c
#
# [3 rows x 2 columns]

# %%
# Series - a 3-row string series with index
pd.Series(['a', 'a', 'c'], index=['x', 'y', 'z'])
# Out:
# Query job d515dbd5-0d6c-472c-b300-299cfb1649ca is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:d515dbd5-0d6c-472c-b300-299cfb1649ca&page=queryresults">Open Job</a>
# Query job 3ff996f9-f27c-411a-ac75-f2a03380f7c4 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:3ff996f9-f27c-411a-ac75-f2a03380f7c4&page=queryresults">Open Job</a>
# Query job bb32bf76-68d4-495e-ab53-ec437f0c2622 is DONE. 42 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:bb32bf76-68d4-495e-ab53-ec437f0c2622&page=queryresults">Open Job</a>
# x    a
# y    a
# z    c
# dtype: string

# %%
# Index
pd.Index(['x', 'y', 'z'])
# Out:
# Query job 844bbe03-3d48-493b-87df-f825a1291c24 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:844bbe03-3d48-493b-87df-f825a1291c24&page=queryresults">Open Job</a>
# Index(['x', 'y', 'z'], dtype='string')

# %% [markdown]
# ## 2. Data types
#
# BigFrames currently supports 11 data types (dtype):
#
# |        | BigFrames dtype string | BigQuery data type | corresponding pandas dtype | pyarrow type |
# | ------ | ------------ | ----------- | ----------- | ----------- |
# |  1     | boolean      | BOOL       | pd.BooleanDtype       | pa.bool_()       |
# |  2     | Float64        | FLOAT64        | pd.Float64Dtype        | pa.float64()        |
# |  3     | Int64        | INT64        | pd.Int64Dtype        | pa.int64()        |
# |  4     | string / string[pyarrow]        | STRING        | pd.StringDtype(storage="pyarrow")        | pa.string()        |
# |  5     | timestamp[us, tz=UTC][pyarrow]        | TIMESTAMP        | pd.ArrowDtype(pa.timestamp("us", tz="UTC"))        | pa.timestamp("us", tz="UTC")        |
# |  6     | timestamp[us][pyarrow]        | DATETIME        | pd.ArrowDtype(pa.timestamp("us"))        | pa.timestamp("us")        |
# |  7     | date32[day][pyarrow]        | DATE        | pd.ArrowDtype(pa.date32())        | pa.date32()        |
# |  8     | time64[us][pyarrow]        | TIME        | pd.ArrowDtype(pa.time64("us"))        | pa.time64("us")        |
# |  9     | decimal128(38, 9)[pyarrow]        | NUMERIC / DECIMAL        | pd.ArrowDtype(pa.decimal128(38, 9))        | pa.decimal128(38, 9)        |
# |  10    | decimal256(76, 38)[pyarrow]        | BIGNUMERIC / BIGDECIMAL        | pd.ArrowDtype(pa.decimal256(76, 38))        | pa.decimal256(76, 38)        |
# |  11    | binary[pyarrow]        | BYTES        | pd.ArrowDtype(pa.binary())        | pa.binary()        |

# %%
# BOOL
pd.Series([True, False, True], dtype=pd.BooleanDtype())
# Out:
# Query job 645f5b5a-2c4a-41a0-9e63-4bde54b84056 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:645f5b5a-2c4a-41a0-9e63-4bde54b84056&page=queryresults">Open Job</a>
# Query job a8aac9b1-8791-4828-ac61-f0af4580486d is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:a8aac9b1-8791-4828-ac61-f0af4580486d&page=queryresults">Open Job</a>
# Query job a8cb4f0f-17b5-4614-9b81-360e19079858 is DONE. 51 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:a8cb4f0f-17b5-4614-9b81-360e19079858&page=queryresults">Open Job</a>
# 0     True
# 1    False
# 2     True
# dtype: boolean

# %%
# FLOAT64
pd.Series([3.1415926535, 2.343512341324, 1321341234.413241234])
# Out:
# Query job f88f13f1-de62-4f7f-a7bf-5596c13248c7 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:f88f13f1-de62-4f7f-a7bf-5596c13248c7&page=queryresults">Open Job</a>
# Query job 59538793-a20f-4b23-b675-0fa42caffb36 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:59538793-a20f-4b23-b675-0fa42caffb36&page=queryresults">Open Job</a>
# Query job 623598ee-7576-46fc-a41c-a0d797105d61 is DONE. 72 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:623598ee-7576-46fc-a41c-a0d797105d61&page=queryresults">Open Job</a>
# 0             3.141593
# 1             2.343512
# 2    1321341234.413241
# dtype: Float64

# %%
# INT64
pd.Series([14342314, 3412341, 754, 626546437654754, 8])
# Out:
# Query job 76fced2f-ade4-4e50-848d-57adfc36cd84 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:76fced2f-ade4-4e50-848d-57adfc36cd84&page=queryresults">Open Job</a>
# Query job a0b3a2a5-7b78-457d-865b-94406b036338 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:a0b3a2a5-7b78-457d-865b-94406b036338&page=queryresults">Open Job</a>
# Query job 232478a0-36fc-44ff-aeae-aebc217a957b is DONE. 120 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:232478a0-36fc-44ff-aeae-aebc217a957b&page=queryresults">Open Job</a>
# 0           14342314
# 1            3412341
# 2                754
# 3    626546437654754
# 4                  8
# dtype: Int64

# %%
# STRING
pd.Series(['apple', 'banana', 'cherry'])
# Out:
# Query job 3adc7833-4886-4408-bf8b-6667af23a401 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:3adc7833-4886-4408-bf8b-6667af23a401&page=queryresults">Open Job</a>
# Query job 8f87151b-6541-4635-a45b-2983a7213f9d is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:8f87151b-6541-4635-a45b-2983a7213f9d&page=queryresults">Open Job</a>
# Query job d77380ef-53b5-4e7f-95b0-f83b4619bd5f is DONE. 71 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:d77380ef-53b5-4e7f-95b0-f83b4619bd5f&page=queryresults">Open Job</a>
# 0     apple
# 1    banana
# 2    cherry
# dtype: string

# %%
# TIMESTAMP
pd.to_datetime(
    [6967025221020, 969611531202, 1356916312000],
    unit='ms'
).astype(pd.ArrowDtype(pa.timestamp("us",tz='UTC')))
# Out:
# Query job ca64ce08-c43d-4ca8-8e38-94ffa2ce5103 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:ca64ce08-c43d-4ca8-8e38-94ffa2ce5103&page=queryresults">Open Job</a>
# Query job 71845c59-4b29-43d5-8cfd-451d60a0457c is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:71845c59-4b29-43d5-8cfd-451d60a0457c&page=queryresults">Open Job</a>
# Query job 15829618-78a3-49d5-a921-cacaa447febd is DONE. 72 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:15829618-78a3-49d5-a921-cacaa447febd&page=queryresults">Open Job</a>
# 0    2190-10-10 20:47:01.020000+00:00
# 1    2000-09-22 08:32:11.202000+00:00
# 2           2012-12-31 01:11:52+00:00
# Name: 0, dtype: timestamp[us, tz=UTC][pyarrow]

# %%
# DATETIME
pd.to_datetime(
    [6967025221020, 969611531202, 1356916312000],
    unit='ms'
).astype(pd.ArrowDtype(pa.timestamp("us")))
# Out:
# Query job c5f0528f-fda6-4e36-b80a-a6ca6f6604d0 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:c5f0528f-fda6-4e36-b80a-a6ca6f6604d0&page=queryresults">Open Job</a>
# Query job 931c5ab9-9851-4cc0-b399-2b929fc9d417 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:931c5ab9-9851-4cc0-b399-2b929fc9d417&page=queryresults">Open Job</a>
# Query job cbed8775-c591-4f99-823a-e03c8854ce9e is DONE. 72 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:cbed8775-c591-4f99-823a-e03c8854ce9e&page=queryresults">Open Job</a>
# 0    2190-10-10 20:47:01.020000
# 1    2000-09-22 08:32:11.202000
# 2           2012-12-31 01:11:52
# Name: 0, dtype: timestamp[us][pyarrow]

# %%
# DATE
pd.to_datetime(
    [6967025221020, 969611531202, 1356916312000],
    unit='ms'
).astype(pd.ArrowDtype(pa.timestamp("us"))).to_pandas().astype(pd.ArrowDtype(pa.date32()))
# Out:
# Query job 30157cb8-d44f-49a2-8de9-2801c6ef6d00 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:30157cb8-d44f-49a2-8de9-2801c6ef6d00&page=queryresults">Open Job</a>
# 0    2190-10-10
# 1    2000-09-22
# 2    2012-12-31
# Name: 0, dtype: date32[day][pyarrow]

# %%
# TIME
pd.to_datetime(
    [6967025221020, 969611531202, 1356916312000],
    unit='ms'
).astype(pd.ArrowDtype(pa.timestamp("us"))).to_pandas().astype(pd.ArrowDtype(pa.time64("us")))
# Out:
# Query job de8e2e8c-2bf8-4ac0-910d-87e30bde330f is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:de8e2e8c-2bf8-4ac0-910d-87e30bde330f&page=queryresults">Open Job</a>
# 0    20:47:01.020000
# 1    08:32:11.202000
# 2           01:11:52
# Name: 0, dtype: time64[us][pyarrow]

# %%
# NUMERIC / DECIMAL
pd.Series([3.1415926535, 2.343512341324, 1321341234.413241234]).astype(pd.ArrowDtype(pa.decimal128(38, 9)))
# Out:
# Query job 9d3e3b65-4a1d-4484-9834-e33ea4ba911e is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:9d3e3b65-4a1d-4484-9834-e33ea4ba911e&page=queryresults">Open Job</a>
# Query job 6e051ebe-0a83-4986-ac99-27de9eb6c7cc is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:6e051ebe-0a83-4986-ac99-27de9eb6c7cc&page=queryresults">Open Job</a>
# Query job 32f37f7d-eec5-48ea-a3c6-0b71b9ecc1f0 is DONE. 96 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:32f37f7d-eec5-48ea-a3c6-0b71b9ecc1f0&page=queryresults">Open Job</a>
# 0             3.141592654
# 1             2.343512341
# 2    1321341234.413241148
# dtype: decimal128(38, 9)[pyarrow]

# %%
# BIGNUMERIC / BIGDECIMAL
pd.Series([3.1415926535, 2.343512341324, 1321341234.413241234]).astype(pd.ArrowDtype(pa.decimal256(76, 38)))
# Out:
# Query job 742875b7-2655-45b2-9cd5-bd702149bcb4 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:742875b7-2655-45b2-9cd5-bd702149bcb4&page=queryresults">Open Job</a>
# Query job 5aef3d3b-594f-4a35-a3c1-bd3ac5a33df5 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:5aef3d3b-594f-4a35-a3c1-bd3ac5a33df5&page=queryresults">Open Job</a>
# Query job 2fe2f457-f798-427e-acf7-6f99ebd1955f is DONE. 144 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:2fe2f457-f798-427e-acf7-6f99ebd1955f&page=queryresults">Open Job</a>
# 0             3.14159265350000005412312020780518651009
# 1             2.34351234132400021437092618725728243589
# 2    1321341234.41324114799499511718750000000000000000
# dtype: decimal256(76, 38)[pyarrow]

# %%
# BYTES
pd.Series([b'apple', b'banana', b'cherry'])
# Out:
# Query job 761a4be0-693c-4152-aa5d-80b179ab5944 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:761a4be0-693c-4152-aa5d-80b179ab5944&page=queryresults">Open Job</a>
# Query job be49d66d-60b1-4dbc-ac7c-407594f807de is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:be49d66d-60b1-4dbc-ac7c-407594f807de&page=queryresults">Open Job</a>
# Query job 025791f7-c69e-406c-bc60-cd0ac13a9bf0 is DONE. 71 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:025791f7-c69e-406c-bc60-cd0ac13a9bf0&page=queryresults">Open Job</a>
# 0     b'apple'
# 1    b'banana'
# 2    b'cherry'
# dtype: binary[pyarrow]

# %% [markdown]
# ## 3. Corner cases
#
# When testing the BigFrames pandas API functions, consider the following corner cases:
# 1. Empty inputs
# 2. Duplicate inputs (e.g. duplicate index value / column name)
# 3. Mixed dtype inputs
# 4. Mixed data structure inputs (e.g. array + dict)
# 5. Multiple (dependent/related) function parameters
# 6. Missing/NaN Values
# 7. Extreme/boundary Values
# 8. Errors cases and Exceptions

# %%
# Empty dataframe
pd.DataFrame()
# Out:
# Query job 2672dadc-2638-40b2-bbbc-f22b516fd66d is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:2672dadc-2638-40b2-bbbc-f22b516fd66d&page=queryresults">Open Job</a>
# Empty DataFrame
# Columns: []
# Index: []
#
# [0 rows x 0 columns]

# %%
# Dataframe with duplicate column name
data1 = {'level1': {'A': [1, 2], 'B': [3, 4]}}
data2 = {'level1': {'C': [5], 'D': [6, 7]}}
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
pd.concat([df1, df2], axis=1)
# Out:
# Load job c6289ace-ab2b-4a70-a3ff-ee5ae14f94ba is DONE. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:c6289ace-ab2b-4a70-a3ff-ee5ae14f94ba&page=queryresults">Open Job</a>
# Load job ed731a0b-cdef-40d7-92ea-99b9019c4f46 is DONE. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:ed731a0b-cdef-40d7-92ea-99b9019c4f46&page=queryresults">Open Job</a>
# Query job cd585afb-68e0-4e79-b50a-5653a008f385 is DONE. 100 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:cd585afb-68e0-4e79-b50a-5653a008f385&page=queryresults">Open Job</a>
# Query job 5a8d13e2-5199-45ee-814e-ef6642cc4e6a is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:5a8d13e2-5199-45ee-814e-ef6642cc4e6a&page=queryresults">Open Job</a>
# Query job 180835c6-a12b-4dc7-b8be-80db83adf2e7 is DONE. 100 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:180835c6-a12b-4dc7-b8be-80db83adf2e7&page=queryresults">Open Job</a>
#    level1  level1
# A  [1, 2]      []
# B  [3, 4]      []
# C      []     [5]
# D      []  [6, 7]
#
# [4 rows x 2 columns]

# %%
# Dataframe with null values
pd.DataFrame({'A': [1, 2, np.nan], 'B': ['a', 'b', 'c']}, index=['x', 'y', 'z'])
# Out:
# Query job bd565cf3-b8e3-490b-979d-d2dfe968b746 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-bugbash-pandas&j=bq:US:bd565cf3-b8e3-490b-979d-d2dfe968b746&page=queryresults">Open Job</a>
#       A  B
# x   1.0  a
# y   2.0  b
# z  <NA>  c
#
# [3 rows x 2 columns]

# %% [markdown]
# # Your test cases
